# %%
welcome="Hey, I would be glad to answer your doubts".center(150)
print("\033[1m"+welcome+"\033[0m")
# Out:
#                                                       Hey, I would be glad to answer your doubts

# %%
print("Please select the subject you have your doubts in:")
Data=[["1","ToC"],["2","DSP"],["3","ML"],["4","Communication System"],["5","French"],["6","Maths"],["7","DSD"]]
head=["Press the number", "Subject"]
teachers=[[["1","VRT"],["2","OPP"],["3","BKP"]],[["1","Subbarao"],["2","Ankita"],["3","Sunil Bhooshan"]],[["1","Sanatan"],["2","Deepti Mishra"]],[["1","Sunil Bhooshan"],["2","Sayantan"]],[["1","Kumudham"],["2","Maud"],["3","Sherlin"],["4","Prashanth"],["5","Nidhi"]],[["1","Biswarup"],["2","Sanjukta"],["3","Mahipal"],["4","Rakhee"],["5","Satyanarayan"]],[["1","R.M. Vemuri"],["2","Harish rachuri"]] ]
from tabulate import tabulate
print(tabulate(Data, stralign="center", headers=head, tablefmt="grid", numalign="center"))
# Out:
# Please select the subject you have your doubts in:
# +--------------------+----------------------+
# |  Press the number  |       Subject        |
# +====================+======================+
# |         1          |         ToC          |
# +--------------------+----------------------+
# |         2          |         DSP          |
# +--------------------+----------------------+
# |         3          |          ML          |
# +--------------------+----------------------+
# |         4          | Communication System |
# +--------------------+----------------------+
# |         5          |        French        |
# +--------------------+----------------------+
# |         6          |        Maths         |
# +--------------------+----------------------+
# |         7          |         DSD          |
# +--------------------+----------------------+

# %%
num=int(input("Waiting for input "))
while((num>len(Data)) or (num<1)):
  print("Invalid Input, Please check the number you have entered")
  num=int(input())
i=1
while i<len(Data):
  if i==num:
    print("Let me check who all teach "+ Data[i-1][1])
    break
  i=i+1
from tabulate import tabulate
print(tabulate(teachers[num-1], headers=["Press the number","Teacher"], tablefmt="grid", numalign="center", stralign="center"))
# Out:
# Waiting for input1
# Let me check who all teach ToC
# +--------------------+-----------+
# |  Press the number  |  Teacher  |
# +====================+===========+
# |         1          |    VRT    |
# +--------------------+-----------+
# |         2          |    OPP    |
# +--------------------+-----------+
# |         3          |    BKP    |
# +--------------------+-----------+

# %%
num1=int(input("Waiting for input "))
while((num1>len(teachers[num-1])) or (num1<1)):
  print("Invalid Input, Please check the number you have entered")
  num1=int(int())

i=1
while i<len(teachers[num-1]):
  if i==num1:
    print("Let me check when is "+ teachers[num-1][i-1][1]+ " available")
    break
  i=i+1
# Out:
# Let me check when is VRT available

# %% [markdown]
# **This section is for Teacher's end**

# %%
# Doubtful please check
# no_S=1
# no_F=1
# time_in=list()
# time_fac=list()
# time_sub=list()
# while(no_S<=len(Data)):
#   print("Tell me, at what all times can you entertain doubts from students")
#   print("Enter time in 24 hour clock format without gap or use of any special character")
#   print("Enter -1 when done")
#   time=input()
#   while(no_F<=len(teachers[no_S-1])):
#     if(time!=-1):
#       time=input()
#       if(time==-1):
#         break
#       else:
#         time_in.append(time)
#     time_fac.append(time_in)
#     no_F=no_F+1;
#   time_sub.append(time_fac)
#   no_S=no_S+1;

# %%
nos=1  #number of subjects
time_avl=list()
while nos<=len(Data):
  nof=1  #number of teachers/faculty
  time_sub=list()
  while nof<=len(teachers[nos-1]):
    time_fac=list()
    time=input("Please enter time in HHMM 24 Hour format & Enter -1 when done ")
    if (time==-1):
      break
    time=time[:2]+":"+time[2:]
    if((int(time[:2])<24) and (int(time[:2])>=00)):
      time_fac.append(time)

    else:
      print("Invalid time")
      continue
    time_sub.append(time_fac)
    #print("ghjvf")
    nof=nof+1
  #print("poi")
  time_avl.append(time_sub)
  nos=nos+1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# ...

# %% [markdown]
# **Now this section is again for students/interested people**

# %%
# print("Thank you for maintaining patience, so this is what I found")
# from tabulated import tabulated
# print(tabulated(available[num-1][num1-1], headers=["Time is 24 hour clock format"], numalign="center", stralign="center", tablefmt="grid"))
